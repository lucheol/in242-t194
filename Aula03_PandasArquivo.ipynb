# %%
import pandas as pd

# %%
df = pd.read_csv('casos_covid_2020.csv')

# %%
df.head()
# Out:
#          date state city place_type  confirmed  deaths  order_for_place  \
# 0  2020-08-28    AP  NaN      state      42625     657              161
# 1  2020-08-27    AP  NaN      state      42285     652              160
# 2  2020-08-26    AP  NaN      state      41981     647              159
# 3  2020-08-25    AP  NaN      state      41553     642              158
# 4  2020-08-24    AP  NaN      state      41254     637              157
#
#    is_last  estimated_population_2019  city_ibge_code  \
# 0     True                   845731.0            16.0
# 1    False                   845731.0            16.0
# 2    False                   845731.0            16.0
# 3    False                   845731.0            16.0
# 4    False                   845731.0            16.0
#
#    confirmed_per_100k_inhabitants  death_rate
# 0                      5040.01863      0.0154
# 1                      4999.81673      0.0154
# 2                      4963.87149      0.0154
# ...

# %%
df_uf = df[df['place_type'] == 'state']

# %%
df_uf
# Out:
#               date state city place_type  confirmed  deaths  order_for_place  \
# 0       2020-08-28    AP  NaN      state      42625     657              161
# 1       2020-08-27    AP  NaN      state      42285     652              160
# 2       2020-08-26    AP  NaN      state      41981     647              159
# 3       2020-08-25    AP  NaN      state      41553     642              158
# 4       2020-08-24    AP  NaN      state      41254     637              157
# 5       2020-08-23    AP  NaN      state      41120     631              156
# 6       2020-08-22    AP  NaN      state      41031     630              155
# 7       2020-08-21    AP  NaN      state      40875     627              154
# 8       2020-08-20    AP  NaN      state      40603     626              153
# 9       2020-08-19    AP  NaN      state      40211     622              152
# 10      2020-08-18    AP  NaN      state      39957     619              151
# ...

# %%
df_uf_atual = df[(df['place_type'] == 'state') & (df['date'] == '2020-08-27')]

# %%
df_uf_atual
# Out:
#               date state city place_type  confirmed  deaths  order_for_place  \
# 1       2020-08-27    AP  NaN      state      42285     652              160
# 2205    2020-08-27    AC  NaN      state      24269     607              164
# 4975    2020-08-27    AM  NaN      state     118083    3616              164
# 13234   2020-08-27    DF  NaN      state     156863    2425              173
# 13738   2020-08-27    AL  NaN      state      77755    1853              170
# 25948   2020-08-27    ES  NaN      state     108662    3105              175
# 36426   2020-08-27    CE  NaN      state     211053    8374              165
# 60619   2020-08-27    GO  NaN      state     128241    2987              169
# 84593   2020-08-27    MS  NaN      state      47152     823              167
# 92355   2020-08-27    BA  NaN      state     247853    5178              173
# 136429  2020-08-27    MA  NaN      state     148923    3402              161
# ...

# %%
df_uf_atual['deaths'].sum()
# Out:
# 118824

# %% [markdown]
# Atividades para casa
# =====
# Criar os seguintes dataframes:
#
# 1. Para testar filtros
#  - Histórico de casos em Santa Rita do Sapucaí
#  - Histórico de casos de todas as cidades de MG
#  - Registro do dia 27 de todas as cidades de São Paulo
#  - Registro do dia 27 de todas as cidades do Brasil
#
#
# 2. Retornar os seguintes dados (para o dia 27):
#  - Total de casos por estado
#  - Total de casos por cidade
#  - Total de mortes por estado
#  - Total de mortes por cidade
#
#
# 3. Próxima aula
#  - Ordenar dados
#  - Agrupar (Qual o total de mortes no BRASIL por dia)
#  - Transformar/aplicar
#  - ...
