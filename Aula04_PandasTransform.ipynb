# %%
import pandas as pd

# %%
df = pd.read_csv('casos_covid_11_set.csv')

# %%
df.head()
# Out:
#          date state city place_type  confirmed  deaths  order_for_place  \
# 0  2020-09-11    AC  NaN      state      26004     636              179
# 1  2020-09-10    AC  NaN      state      25877     635              178
# 2  2020-09-09    AC  NaN      state      25668     631              177
# 3  2020-09-08    AC  NaN      state      25494     630              176
# 4  2020-09-07    AC  NaN      state      25469     624              175
#
#    is_last  estimated_population_2019  city_ibge_code  \
# 0     True                   881935.0            12.0
# 1    False                   881935.0            12.0
# 2    False                   881935.0            12.0
# 3    False                   881935.0            12.0
# 4    False                   881935.0            12.0
#
#    confirmed_per_100k_inhabitants  death_rate
# 0                      2948.51661      0.0245
# 1                      2934.11646      0.0245
# 2                      2910.41857      0.0246
# ...

# %%
df_str = df[df['city'].astype(str).str.contains('Santa Rita do Sapucaí')] # filtro

# %%
df_str.size
# Out:
# 1476

# %%
df_str = df_str[['city', 'date', 'confirmed', 'deaths']] # seleção de colunas

# %%
# Ordenação
df_str.sort_values('date', inplace=True)
# Out:
# /Users/lucheol/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_str
# Out:
#                          city        date  confirmed  deaths
# 279956  Santa Rita do Sapucaí  2020-09-09        149       7
# 279957  Santa Rita do Sapucaí  2020-09-08        149       7
# 279958  Santa Rita do Sapucaí  2020-09-05        149       8
# 279959  Santa Rita do Sapucaí  2020-09-04        149       8
# 279960  Santa Rita do Sapucaí  2020-09-02        117       4
# 279961  Santa Rita do Sapucaí  2020-09-01        117       3
# 279962  Santa Rita do Sapucaí  2020-08-31        117       3
# 279963  Santa Rita do Sapucaí  2020-08-30        103       2
# 279964  Santa Rita do Sapucaí  2020-08-29        103       2
# 279965  Santa Rita do Sapucaí  2020-08-28        103       2
# 279966  Santa Rita do Sapucaí  2020-08-27        103       2
# 279967  Santa Rita do Sapucaí  2020-08-26        103       2
# 279968  Santa Rita do Sapucaí  2020-08-25        100       2
# 279969  Santa Rita do Sapucaí  2020-08-24         77       2
# ...

# %%
df_str2 = df[df['city'].astype(str).str.contains('Santa Rita do Sapucaí')].copy()

# %%
df_str2.sort_values('date', inplace=True)

# %%
df_str2.reset_index(inplace=True)

# %%
df_str2 = df_str2[['date', 'city', 'confirmed', 'deaths']].copy()

# %%
df_str2.rename(columns={'date': 'Data', 'city': 'Cidade', 'confirmed': 'Casos confirmados', 'deaths': 'Mortes confirmadas'}, inplace=True)

# %%
df_str2
# Out:
#            Data                 Cidade  Casos confirmados  Mortes confirmadas
# 0    2020-04-30  Santa Rita do Sapucaí                  1                   0
# 1    2020-05-01  Santa Rita do Sapucaí                  1                   0
# 2    2020-05-02  Santa Rita do Sapucaí                  1                   0
# 3    2020-05-03  Santa Rita do Sapucaí                  1                   0
# 4    2020-05-04  Santa Rita do Sapucaí                  1                   0
# 5    2020-05-05  Santa Rita do Sapucaí                  1                   0
# 6    2020-05-06  Santa Rita do Sapucaí                  1                   0
# 7    2020-05-07  Santa Rita do Sapucaí                  1                   0
# 8    2020-05-08  Santa Rita do Sapucaí                  1                   0
# 9    2020-05-09  Santa Rita do Sapucaí                  1                   0
# 10   2020-05-10  Santa Rita do Sapucaí                  1                   0
# ...

# %%
df_str2.plot.line(y=['Casos confirmados', 'Mortes confirmadas'])
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf

# %%
# Histórico de casos de todas as cidades de MG
df[(df['state'] == 'MG') & (df['place_type'] == 'city')]
# Out:
#               date state                 city place_type  confirmed  deaths  \
# 213351  2020-09-09    MG  Abadia dos Dourados       city         61       1
# 213352  2020-09-08    MG  Abadia dos Dourados       city         61       1
# 213353  2020-09-05    MG  Abadia dos Dourados       city         57       1
# 213354  2020-09-04    MG  Abadia dos Dourados       city         57       1
# 213355  2020-09-02    MG  Abadia dos Dourados       city         57       1
# 213356  2020-09-01    MG  Abadia dos Dourados       city         57       1
# 213357  2020-08-31    MG  Abadia dos Dourados       city         57       1
# 213358  2020-08-30    MG  Abadia dos Dourados       city         54       1
# 213359  2020-08-29    MG  Abadia dos Dourados       city         54       1
# 213360  2020-08-28    MG  Abadia dos Dourados       city         54       1
# 213361  2020-08-27    MG  Abadia dos Dourados       city         51       1
# ...

# %%
# Registro do dia 27 de todas as cidades de São Paulo
df[(df['state'] == 'SP') & (df['place_type'] == 'city') & (df['date'] == '2020-08-27')]
# Out:
#               date state                    city place_type  confirmed  \
# 577691  2020-08-27    SP              Adamantina       city        250
# 577845  2020-08-27    SP                  Adolfo       city         84
# 577975  2020-08-27    SP                   Aguaí       city        240
# 578112  2020-08-27    SP                  Agudos       city        464
# 578270  2020-08-27    SP                Alambari       city         56
# 578414  2020-08-27    SP       Alfredo Marcondes       city         42
# 578525  2020-08-27    SP                  Altair       city         33
# 578639  2020-08-27    SP             Altinópolis       city        183
# 578756  2020-08-27    SP             Alto Alegre       city         51
# 578877  2020-08-27    SP                Alumínio       city        139
# 578995  2020-08-27    SP             Alvinlândia       city         23
# 579092  2020-08-27    SP               Americana       city       3692
# ...

# %%
# Registro do dia 27 de todas as cidades do Brasil
df[(df['place_type'] == 'city') & (df['date'] == '2020-08-27')]
# Out:
#               date state                    city place_type  confirmed  \
# 192     2020-08-27    AC              Acrelândia       city        425
# 352     2020-08-27    AC            Assis Brasil       city        490
# 479     2020-08-27    AC               Brasiléia       city       1101
# 598     2020-08-27    AC                  Bujari       city        362
# 748     2020-08-27    AC                Capixaba       city        246
# 868     2020-08-27    AC         Cruzeiro do Sul       city       3081
# 1013    2020-08-27    AC          Epitaciolândia       city        483
# 1134    2020-08-27    AC                   Feijó       city       1069
# 1260    2020-08-27    AC                  Jordão       city        144
# 1370    2020-08-27    AC           Manoel Urbano       city        266
# 1485    2020-08-27    AC    Marechal Thaumaturgo       city        326
# 1601    2020-08-27    AC             Mâncio Lima       city        641
# ...

# %%
df[(df['state'] == 'SP') & (df['place_type'] == 'city') & (df['date'] >= '2020-08-20') & (df['date'] <= '2020-08-27')]
# Out:
#               date state                city place_type  confirmed  deaths  \
# 577691  2020-08-27    SP          Adamantina       city        250       7
# 577692  2020-08-26    SP          Adamantina       city        248       7
# 577693  2020-08-25    SP          Adamantina       city        244       7
# 577694  2020-08-24    SP          Adamantina       city        243       7
# 577695  2020-08-23    SP          Adamantina       city        242       7
# 577696  2020-08-22    SP          Adamantina       city        235       7
# 577697  2020-08-21    SP          Adamantina       city        230       7
# 577698  2020-08-20    SP          Adamantina       city        230       7
# 577845  2020-08-27    SP              Adolfo       city         84       3
# 577846  2020-08-26    SP              Adolfo       city         78       3
# 577847  2020-08-25    SP              Adolfo       city         77       3
# ...

# %%
df_uf = df[(df['is_last'] == True) & (df['place_type'] == 'state')][['date','state', 'confirmed', 'deaths']]

# %%
df_uf
# Out:
#               date state  confirmed  deaths
# 0       2020-09-11    AC      26004     636
# 3070    2020-09-11    AP      45665     677
# 5448    2020-09-11    AM     126423    3883
# 14279   2020-09-11    AL      81440    1965
# 27842   2020-09-11    DF     174549    2867
# 28388   2020-09-11    ES     118814    3332
# 39828   2020-09-11    CE     226021    8683
# 66440   2020-09-11    GO     162204    3761
# 93622   2020-09-11    BA     279509    5866
# 143143  2020-09-10    MS      58304    1035
# 152024  2020-09-11    MA     161994    3560
# 181096  2020-09-11    MT     104529    3093
# 193024  2020-09-11    PA     213655    6307
# 213164  2020-09-11    MG     246149    6114
# 296410  2020-09-11    PE     135643    7817
# 322346  2020-09-11    PB     112018    2604
# 349715  2020-09-10    PI      85225    1947
# 375499  2020-09-11    PR     150668    3781
# 420208  2020-09-10    RR      46102     609
# 422595  2020-09-11    RO      60068    1231
# ...

# %%
df_uf.plot.bar(x='state', y='confirmed')

# %%
df_cidades = df[(df['is_last'] == True) & (df.place_type == 'city')]

# %%
df_cidades.sort_values('confirmed', ascending=False)[:10]
# Out:
#               date state            city place_type  confirmed  deaths  \
# 649947  2020-09-10    SP       São Paulo       city     271505   11933
# 28030   2020-09-11    DF        Brasília       city     153321    2630
# 439490  2020-09-10    RJ  Rio de Janeiro       city      94896   10074
# 133096  2020-09-09    BA        Salvador       city      79722    2488
# 48290   2020-09-11    CE       Fortaleza       city      47799    3818
# 10677   2020-09-10    AM          Manaus       city      44709    2419
# 77199   2020-09-11    GO         Goiânia       city      39565    1068
# 219315  2020-09-09    MG  Belo Horizonte       city      35983    1076
# 195726  2020-09-10    PA           Belém       city      34319    2125
# 420653  2020-09-09    RR       Boa Vista       city      34074     472
#
#         order_for_place  is_last  estimated_population_2019  city_ibge_code  \
# 649947              186     True                 12252023.0       3550308.0
# ...

# %%
# Qual o total de mortes no Brasil por dia

df_total = df[df.place_type == 'state']

# %%
df_total[df_total['date'] == '2020-09-11']
# Out:
#               date state city place_type  confirmed  deaths  order_for_place  \
# 0       2020-09-11    AC  NaN      state      26004     636              179
# 3070    2020-09-11    AP  NaN      state      45665     677              175
# 5448    2020-09-11    AM  NaN      state     126423    3883              179
# 14279   2020-09-11    AL  NaN      state      81440    1965              185
# 27842   2020-09-11    DF  NaN      state     174549    2867              188
# 28388   2020-09-11    ES  NaN      state     118814    3332              190
# 39828   2020-09-11    CE  NaN      state     226021    8683              180
# 66440   2020-09-11    GO  NaN      state     162204    3761              184
# 93622   2020-09-11    BA  NaN      state     279509    5866              188
# 152024  2020-09-11    MA  NaN      state     161994    3560              176
# 181096  2020-09-11    MT  NaN      state     104529    3093              173
# ...

# %%
df_total = df_total.groupby('date')['confirmed', 'deaths'].sum()

# %%
df_total
# Out:
#             confirmed  deaths
# date
# 2020-02-25          1       0
# 2020-02-26          1       0
# 2020-02-27          1       0
# 2020-02-28          2       0
# 2020-02-29          2       0
# 2020-03-01          2       0
# 2020-03-02          2       0
# 2020-03-03          2       0
# 2020-03-04          3       0
# 2020-03-05          8       0
# 2020-03-06         14       0
# 2020-03-07         17       0
# 2020-03-08         23       0
# 2020-03-09         22       0
# 2020-03-10         26       0
# 2020-03-11         39       0
# 2020-03-12         89       0
# 2020-03-13         35       0
# 2020-03-14        100       0
# 2020-03-15         71       0
# 2020-03-16        278       0
# 2020-03-17        267       1
# 2020-03-18        514       3
# 2020-03-19        635       7
# 2020-03-20        864       9
# 2020-03-21       1131      18
# 2020-03-22       1584      25
# 2020-03-23       1926      34
# 2020-03-24       2255      47
# 2020-03-25       2565      59
# ...

# %%
df_total.plot.line()

# %%
# total de mortes e casos confirmados por dia por estado

# %%
df_dia_uf = df[df.place_type == 'city'].groupby(['date', 'state'])['confirmed', 'deaths'].sum()

# %%
df_dia_uf.head()
# Out:
#                   confirmed  deaths
# date       state
# 2020-02-25 SP             1       0
# 2020-02-26 SP             1       0
# 2020-02-27 SP             1       0
# 2020-02-28 SP             2       0
# 2020-02-29 SP             2       0

# %%
df_dia_uf.plot()

# %% [markdown]
# Próximos passos
# ---------
#
# Vamos pegar dados por dia das seguintes cidades:
#
#
# - Três Corações
# - Santa Rita do Sapucaí
# - Cachoeira de Minas
# - Piranguinho
# - Itajubá
# - Poços de Caldas
# - Pouso Alegre
#
#
# 1. Queremos construir um "consumidor" que pega os dados de casos confirmados e mortes por dia. (EXTRACT)
# 2. Capturar/processar o total de casos/mortes por dia (não o acumulado)(TRANSFORM)
# 3. Armazenar em banco próprio (LOAD) / Infraestrutura (docker)
# 4. Comparar as cidades (DASHBOARD)
# 5. Processo automático, dentro de um servidor/diário
